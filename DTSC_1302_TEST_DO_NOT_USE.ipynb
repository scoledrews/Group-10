# %% [markdown]
# <a href="https://colab.research.google.com/github/scoledrews/Group-10/blob/main/DTSC_1302_TEST_DO_NOT_USE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/scoledrews/Group-10/refs/heads/main/DATASET%20E.csv?token=GHSAT0AAAAAACZ6YVYK67OMQBCIFUJFLCOWZZI6PJA"
df = pd.read_csv(url)
df.head(5)
# Out:
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# 2                                        410000
# 3                                        234000
# 4                                       3826000
#
#    Employer Health Insurance Coverage (2015)  \
# 0                                    2545000
# ...

# %%
# !git clone https://github.com/scoledrews/Group-10
# %cd
df = pd.read_csv("https://raw.githubusercontent.com/scoledrews/Group-10/refs/heads/main/DATASET%20E.csv?token=GHSAT0AAAAAACZ6YVYLYKGKJVEY7HWHE33QZZI7DUQ")
df.head(5)
# Out:
# Cloning into 'Group-10'...
# fatal: could not read Username for 'https://github.com': No such device or address
# [Errno 2] No such file or directory: 'https://github.com/scoledrews/Group-10/tree/main'
# /content/dtsc/dtsc/dtsc/dtsc
#         State Uninsured Rate (2010) Uninsured Rate (2015)  \
# 0    Alabama                  14.6%                 10.1%
# 1     Alaska                  19.9%                 14.9%
# 2    Arizona                  16.9%                 10.8%
# 3   Arkansas                  17.5%                  9.5%
# 4  California                 18.5%                  8.6%
#
#   Uninsured Rate Change (2010-2015)  \
# 0                            -4.5%
# 1                              -5%
# 2                            -6.1%
# 3                              -8%
# 4                            -9.9%
#
#    Health Insurance Coverage Change (2010-2015)  \
# 0                                        215000
# 1                                         36000
# ...
